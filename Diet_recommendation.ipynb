# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/harip/Downloads/Dataset.csv")

# %%
df.sample(3)
# Out:
#       Unnamed: 0  age  weight(kg)  height(m) gender        BMI       BMR  \
# 2856        6250   15   52.843259   1.598703      M  20.675411  1487.304
# 9662       21791   43   89.866373   1.631678      M  33.754244  1820.608
# 4395        8829   19   57.736710   1.632094      M  21.675132  1543.840
#
#       activity_level  calories_to_maintain_weight  BMI_tags  Label
# 2856             1.9                    2825.8776         8     21
# 9662             1.3                    2366.7904         9     29
# 4395             1.7                    2624.5280         8     20

# %%
df.shape
# Out:
# (10726, 11)

# %%
df.drop(columns=["Unnamed: 0","BMI_tags","Label"],inplace=True)

# %%
df
# Out:
#        age  weight(kg)  height(m) gender        BMI       BMR  activity_level  \
# 0        2   16.097862   0.932025      F  18.531612   958.584             1.2
# 1        4   14.619374   0.916687      F  17.397496   932.383             1.7
# 2        4   17.899918   0.997288      F  17.997414   977.578             1.9
# 3        3   13.532880   1.022786      F  12.936609   944.689             1.9
# 4        4   17.039484   1.053977      M  15.338909   799.229             1.9
# ...    ...         ...        ...    ...        ...       ...             ...
# 10721   72   95.444236   1.631113      F  35.874169  1510.154             1.3
# 10722   85   97.976899   1.631409      F  36.812724  1473.418             1.7
# 10723   50   97.761259   1.631864      F  36.711217  1635.925             1.7
# 10724   57   96.829324   1.631290      F  36.386871  1593.981             1.3
# 10725   63   97.615186   1.633168      M  36.597850  1791.512             1.2
#
# ...

# %%
df["activity_level"].value_counts()
# Out:
# activity_level
# 1.3    2732
# 1.5    2491
# 1.2    2004
# 1.7    1933
# 1.9    1566
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# age                            0
# weight(kg)                     0
# height(m)                      0
# gender                         0
# BMI                            0
# BMR                            0
# activity_level                 0
# calories_to_maintain_weight    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df["gender"]=le.fit_transform(df["gender"])

# %%
df
# Out:
#        age  weight(kg)  height(m)  gender        BMI       BMR  \
# 0        2   16.097862   0.932025       0  18.531612   958.584
# 1        4   14.619374   0.916687       0  17.397496   932.383
# 2        4   17.899918   0.997288       0  17.997414   977.578
# 3        3   13.532880   1.022786       0  12.936609   944.689
# 4        4   17.039484   1.053977       1  15.338909   799.229
# ...    ...         ...        ...     ...        ...       ...
# 10721   72   95.444236   1.631113       0  35.874169  1510.154
# 10722   85   97.976899   1.631409       0  36.812724  1473.418
# 10723   50   97.761259   1.631864       0  36.711217  1635.925
# 10724   57   96.829324   1.631290       0  36.386871  1593.981
# 10725   63   97.615186   1.633168       1  36.597850  1791.512
#
#        activity_level  calories_to_maintain_weight
# 0                 1.2                    1150.3008
# 1                 1.7                    1585.0511
# 2                 1.9                    1857.3982
# ...

# %%
x=df.iloc[:, :-1]

# %%
x
# Out:
#        age  weight(kg)  height(m)  gender        BMI       BMR  activity_level
# 0        2   16.097862   0.932025       0  18.531612   958.584             1.2
# 1        4   14.619374   0.916687       0  17.397496   932.383             1.7
# 2        4   17.899918   0.997288       0  17.997414   977.578             1.9
# 3        3   13.532880   1.022786       0  12.936609   944.689             1.9
# 4        4   17.039484   1.053977       1  15.338909   799.229             1.9
# ...    ...         ...        ...     ...        ...       ...             ...
# 10721   72   95.444236   1.631113       0  35.874169  1510.154             1.3
# 10722   85   97.976899   1.631409       0  36.812724  1473.418             1.7
# 10723   50   97.761259   1.631864       0  36.711217  1635.925             1.7
# 10724   57   96.829324   1.631290       0  36.386871  1593.981             1.3
# 10725   63   97.615186   1.633168       1  36.597850  1791.512             1.2
#
# ...

# %%
y=df.iloc[:, [-1]]

# %%
y
# Out:
#        calories_to_maintain_weight
# 0                        1150.3008
# 1                        1585.0511
# 2                        1857.3982
# 3                        1794.9091
# 4                        1518.5351
# ...                            ...
# 10721                    1963.2002
# 10722                    2504.8106
# 10723                    2781.0725
# 10724                    2072.1753
# 10725                    2149.8144
#
# [10726 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
xtrain
# Out:
#       age  weight(kg)  height(m)  gender        BMI       BMR  activity_level
# 8658   41   86.769843   1.632664       1  32.551808  1792.279             1.2
# 9424   44   92.406647   1.632474       1  34.674551  1849.008             1.5
# 9103   44   93.335631   1.630817       1  35.094340  1860.907             1.2
# 1103    7   28.003668   1.232089       0  18.447227  1100.390             1.7
# 8817   42   92.791032   1.632373       0  34.823076  1625.897             1.2
# ...   ...         ...        ...     ...        ...       ...             ...
# 5734   23   62.796401   1.631686       1  23.586400  1585.754             1.5
# 5191   24   62.012472   1.632918       1  23.256814  1568.830             1.3
# 5390   24   62.657725   1.630833       0  23.558921  1420.956             1.3
# 860     6   20.017328   1.275880       1  12.296635   937.378             1.9
# 7270   32   73.259209   1.631772       1  27.513347  1667.937             1.3
#
# [8580 rows x 7 columns]

# %%
xtest
# Out:
#       age  weight(kg)  height(m)  gender        BMI       BMR  activity_level
# 958     7   25.683882   1.290001       1  15.434079  1015.270             1.5
# 107     5   17.873909   0.856328       0  24.374715   948.665             1.9
# 2009   11   38.947414   1.466716       0  18.104500  1226.537             1.2
# 2955   15   54.273921   1.593114       0  21.384424  1376.359             1.9
# 1355    6   27.201704   1.260192       0  17.128629  1102.169             1.7
# ...   ...         ...        ...     ...        ...       ...             ...
# 5646   24   60.874186   1.632126       0  22.852088  1404.054             1.7
# 1018    8   25.268432   1.304202       0  14.855552  1081.691             1.5
# 7248   30   78.221082   1.632958       1  29.334174  1750.108             1.2
# 7771   37   80.597744   1.632706       1  30.234778  1734.942             1.2
# 1760   12   32.933118   1.545688       1  13.784443  1208.428             1.2
#
# [2146 rows x 7 columns]

# %%
ytest
# Out:
#       calories_to_maintain_weight
# 958                     1522.9050
# 107                     1802.4635
# 2009                    1471.8444
# 2955                    2615.0821
# 1355                    1873.6873
# ...                           ...
# 5646                    2386.8918
# 1018                    1622.5365
# 7248                    2100.1296
# 7771                    2081.9304
# 1760                    1450.1136
#
# [2146 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import classification_report,mean_squared_error

# %%
model=LinearRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypred=model.predict(xtest)

# %%
print(mean_squared_error(ypred,ytest))
# Out:
# 2059.2172725572523

# %%
import numpy as np

# %%
data=np.array([[7,25.657676,1.29009,1,15.45645,1015.90876,1.5]])

# %%
re=model.predict(data)
# Out:
# C:\Users\harip\anaconda3\anaconda\New folder\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(re)
# Out:
# [[1453.64993641]]

# %%
import pickle

# %%
pickle.dump(model,open("diet.pkl","wb"))
